# %%
import pandas as pd

# %%
# %store -r puttingcont
# %store -r OTTcont
# %store -r ARTGcont
# %store -r ATGcont
# %store -r dfmaster22

# %%
dfmaster22
# Out:
#           PLAYER NAME  AVERAGE_putting_scaled  AVERAGE_OTT_scaled  \
# 0      Tyrrell Hatton                1.000000            0.362098
# 1           Brian Gay                0.975674            0.103215
# 2       Cameron Smith                0.911101            0.382403
# 3       Lucas Herbert                0.865989            0.208122
# 4         Kelly Kraft                0.849624            0.195854
# ..                ...                     ...                 ...
# 200   Joseph Bramlett                0.113667            0.624788
# 201         Luke List                0.086245            0.711929
# 202  Charl Schwartzel                0.050420            0.144247
# 203     Brett Drewitt                0.031402            0.441201
# 204      Kyle Stanley                0.000000            0.549915
#
#      AVERAGE_ARTG_scaled  AVERAGE_ATG_scaled  Final Score
# 0               0.658735            0.705071     0.525729
# ...

# %%
dfmaster22['Final Score']=''
dfmaster22
# Out:
#           PLAYER NAME  AVERAGE_putting_scaled  AVERAGE_OTT_scaled  \
# 0      Tyrrell Hatton                1.000000            0.362098
# 1           Brian Gay                0.975674            0.103215
# 2       Cameron Smith                0.911101            0.382403
# 3       Lucas Herbert                0.865989            0.208122
# 4         Kelly Kraft                0.849624            0.195854
# ..                ...                     ...                 ...
# 200   Joseph Bramlett                0.113667            0.624788
# 201         Luke List                0.086245            0.711929
# 202  Charl Schwartzel                0.050420            0.144247
# 203     Brett Drewitt                0.031402            0.441201
# 204      Kyle Stanley                0.000000            0.549915
#
#      AVERAGE_ARTG_scaled  AVERAGE_ATG_scaled Final Score
# 0               0.658735            0.705071
# 1               0.710708            0.000000
# ...

# %%
dfmaster22['Final Score']=(dfmaster22['AVERAGE_putting_scaled']*puttingcont)+(dfmaster22['AVERAGE_OTT_scaled']*OTTcont)+(dfmaster22['AVERAGE_ARTG_scaled']*ARTGcont)+(dfmaster22['AVERAGE_ATG_scaled']*ATGcont)
dfmaster22
# Out:
#           PLAYER NAME  AVERAGE_putting_scaled  AVERAGE_OTT_scaled  \
# 0      Tyrrell Hatton                1.000000            0.362098
# 1           Brian Gay                0.975674            0.103215
# 2       Cameron Smith                0.911101            0.382403
# 3       Lucas Herbert                0.865989            0.208122
# 4         Kelly Kraft                0.849624            0.195854
# ..                ...                     ...                 ...
# 200   Joseph Bramlett                0.113667            0.624788
# 201         Luke List                0.086245            0.711929
# 202  Charl Schwartzel                0.050420            0.144247
# 203     Brett Drewitt                0.031402            0.441201
# 204      Kyle Stanley                0.000000            0.549915
#
#      AVERAGE_ARTG_scaled  AVERAGE_ATG_scaled  Final Score
# 0               0.658735            0.705071     0.525729
# ...

# %%
dfmaster22wellsfargofinal = dfmaster22[['PLAYER NAME', 'Final Score']]
dfmaster22wellsfargofinal
# Out:
#           PLAYER NAME  Final Score
# 0      Tyrrell Hatton     0.525729
# 1           Brian Gay     0.271301
# 2       Cameron Smith     0.559936
# 3       Lucas Herbert     0.334888
# 4         Kelly Kraft     0.293707
# ..                ...          ...
# 200   Joseph Bramlett     0.529748
# 201         Luke List     0.651997
# 202  Charl Schwartzel     0.206073
# 203     Brett Drewitt     0.425519
# 204      Kyle Stanley     0.450264
#
# [205 rows x 2 columns]

# %%
pd.set_option('display.max_rows', None)
dfmaster22wellsfargofinal.sort_values('Final Score', ascending=False)
# Out:
#                  PLAYER NAME  Final Score
# 128                 Jon Rahm     0.831009
# 69            Keith Mitchell     0.719075
# 48             Cameron Young     0.714473
# 169           Will Zalatoris     0.695341
# 61                Sungjae Im     0.690942
# 96             Corey Conners     0.686005
# 58           Collin Morikawa     0.682889
# 25           Patrick Cantlay     0.681998
# 24             Sergio Garcia     0.679345
# 102            Justin Thomas     0.678741
# 45          Matt Fitzpatrick     0.672636
# 9             Billy Horschel     0.652520
# 201                Luke List     0.651997
# 49             Daniel Berger     0.648336
# 126               Chris Kirk     0.647754
# 109          Joaquin Niemann     0.645500
# 47            Viktor Hovland     0.645050
# 112          Jhonattan Vegas     0.644836
# 60         Xander Schauffele     0.642234
# 111         Louis Oosthuizen     0.636293
# 144           Keegan Bradley     0.634186
# ...
