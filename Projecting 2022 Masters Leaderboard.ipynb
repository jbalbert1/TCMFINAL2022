# %%
import pandas as pd

# %%
# %store -r puttingcontmasters
# %store -r OTTcontmasters
# %store -r ARTGcontmasters
# %store -r ATGcontmasters
# %store -r dfmaster22

# %%
dfmaster22
# Out:
#           PLAYER NAME  AVERAGE_putting_scaled  AVERAGE_OTT_scaled  \
# 0      Tyrrell Hatton                1.000000            0.362098
# 1           Brian Gay                0.975674            0.103215
# 2       Cameron Smith                0.911101            0.382403
# 3       Lucas Herbert                0.865989            0.208122
# 4         Kelly Kraft                0.849624            0.195854
# ..                ...                     ...                 ...
# 200   Joseph Bramlett                0.113667            0.624788
# 201         Luke List                0.086245            0.711929
# 202  Charl Schwartzel                0.050420            0.144247
# 203     Brett Drewitt                0.031402            0.441201
# 204      Kyle Stanley                0.000000            0.549915
#
#      AVERAGE_ARTG_scaled  AVERAGE_ATG_scaled
# 0               0.658735            0.705071
# 1               0.710708            0.000000
# ...

# %%
dfmaster22['Final Score']=''
dfmaster22
# Out:
#           PLAYER NAME  AVERAGE_putting_scaled  AVERAGE_OTT_scaled  \
# 0      Tyrrell Hatton                1.000000            0.362098
# 1           Brian Gay                0.975674            0.103215
# 2       Cameron Smith                0.911101            0.382403
# 3       Lucas Herbert                0.865989            0.208122
# 4         Kelly Kraft                0.849624            0.195854
# ..                ...                     ...                 ...
# 200   Joseph Bramlett                0.113667            0.624788
# 201         Luke List                0.086245            0.711929
# 202  Charl Schwartzel                0.050420            0.144247
# 203     Brett Drewitt                0.031402            0.441201
# 204      Kyle Stanley                0.000000            0.549915
#
#      AVERAGE_ARTG_scaled  AVERAGE_ATG_scaled Final Score
# 0               0.658735            0.705071
# 1               0.710708            0.000000
# ...

# %%
dfmaster22['Final Score']=(dfmaster22['AVERAGE_putting_scaled']*puttingcontmasters)+(dfmaster22['AVERAGE_OTT_scaled']*OTTcontmasters)+(dfmaster22['AVERAGE_ARTG_scaled']*ARTGcontmasters)+(dfmaster22['AVERAGE_ATG_scaled']*ATGcontmasters)
dfmaster22
# Out:
#           PLAYER NAME  AVERAGE_putting_scaled  AVERAGE_OTT_scaled  \
# 0      Tyrrell Hatton                1.000000            0.362098
# 1           Brian Gay                0.975674            0.103215
# 2       Cameron Smith                0.911101            0.382403
# 3       Lucas Herbert                0.865989            0.208122
# 4         Kelly Kraft                0.849624            0.195854
# ..                ...                     ...                 ...
# 200   Joseph Bramlett                0.113667            0.624788
# 201         Luke List                0.086245            0.711929
# 202  Charl Schwartzel                0.050420            0.144247
# 203     Brett Drewitt                0.031402            0.441201
# 204      Kyle Stanley                0.000000            0.549915
#
#      AVERAGE_ARTG_scaled  AVERAGE_ATG_scaled  Final Score
# 0               0.658735            0.705071     0.658469
# ...

# %%
masters22final = dfmaster22[['PLAYER NAME', 'Final Score']]
masters22final
# Out:
#           PLAYER NAME  Final Score
# 0      Tyrrell Hatton     0.658469
# 1           Brian Gay     0.310937
# 2       Cameron Smith     0.776684
# 3       Lucas Herbert     0.364832
# 4         Kelly Kraft     0.251916
# ..                ...          ...
# 200   Joseph Bramlett     0.515255
# 201         Luke List     0.777847
# 202  Charl Schwartzel     0.405226
# 203     Brett Drewitt     0.567915
# 204      Kyle Stanley     0.441295
#
# [205 rows x 2 columns]

# %%
pd.set_option('display.max_rows', None)
masters22final.sort_values('Final Score', ascending=False)
# Out:
#                  PLAYER NAME  Final Score
# 87            Russell Henley     0.847576
# 102            Justin Thomas     0.804839
# 84               Talor Gooch     0.798639
# 169           Will Zalatoris     0.793466
# 49             Daniel Berger     0.780115
# 109          Joaquin Niemann     0.779534
# 201                Luke List     0.777847
# 2              Cameron Smith     0.776684
# 45          Matt Fitzpatrick     0.774062
# 50               Adam Hadwin     0.759223
# 126               Chris Kirk     0.754472
# 147         Hideki Matsuyama     0.748561
# 31                 Sam Burns     0.747050
# 144           Keegan Bradley     0.739200
# 139                 Tom Hoge     0.728809
# 15         Scottie Scheffler     0.724497
# 61                Sungjae Im     0.721284
# 183             Martin Laird     0.705638
# 13               Shane Lowry     0.704827
# 20           Matthias Schwab     0.701505
# 60         Xander Schauffele     0.699282
# ...
